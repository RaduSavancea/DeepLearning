# %% [markdown]
# # Foundations

# %% [markdown]
# ## General Information
#  We'll use Python and PyTorch in this course. Therefore, to prepare you for what is to come, the following tasks are intended to refresh your programming skills in Python and PyTorch. Feel free to use code you have already written in other courses such as Deep Learning. If you stumble, look at the end of the respective task, there are suggestions you can follow that can possibly help you to solve the task. These suggestions do not necessarily have to be implemented, you can also approach it in a completely different way.
#
#  *Remember to take your prepared notebook to the course (e.g. via a Cloud-Service) so you don't have to write things of frequent use like a training loop or a basic PyTorch model class from scratch again. You can also bring any other helpful code you have written w.r.t. Python and PyTorch.*
#
#  TensorBoard use is optional. If you do not want to use TensorBoard, then please use other means to keep track of your models' training progress (i.e. loss curve) and to compare them.

# %% [markdown]
# ## GWDG Juypter Cloud
# All the tasks here can be solved on the CPU in a reasonable amount of time. However, if your local machine should not be powerful enough or if you have troubles setting up an environment with all the packages, you can also use the GWDG Jupyter Cloud. Not every package required by the tasks is given by default on Jupyter Cloud. Therefore, you will need to set up your own environment on Jupyter Cloud. On how to do it, please look into *JupyterCloud_instructions.pdf* . One downside of using the cloud is that you cannot use *TensorBoard*. More on *TensorBoard* below.

# %% [markdown]
# ## Environment Setup
# To set up the environment on your local machine, you may want to consider installing *Miniconda* *(see: https://docs.conda.io/en/latest/miniconda.html)*, which is a package manager that enables you to install *Python* and various packages required for your projects within an isolated environment. This allows you to have different *Python* versions and packages for different projects, and the package manager also manages dependencies between packages and installs them as necessary, which can save you time and effort.
#
# After installing *Miniconda*, you can install a range of packages from sources such as *Anaconda* *(see: https://anaconda.org/)*, *conda-forge*, or *PyPI*.
#
# Once *Miniconda* is installed, you can use various conda commands in cmd.exe(Windows)/Terminal(MacOS/Linux) *(see: https://docs.conda.io/projects/conda/en/latest/commands.html)*.
#
# To create an environment specifically with the *dl_synthesis.txt* file that you have downloaded from StudIP, you can use the following commands:
#
#     `conda create -n DLsynthesis python=3.9.15`
#     `conda activate DLsynthesis`
#     `conda install -y --file DIR_OF_dl_synthesis.txt -c conda-forge -c pytorch`
#     `conda deactivate`
#
# Note that *DIR_OF_dl_synthesis.txt* should be replaced with the directory of the downloaded *dl_synthesis.txt* file.
# The file *dl_synthesis.txt* lists the libraries we used in our solution for this notebook.
#
# In IDEs such as *VSCode*, the environment will be automatically detected and you can use it by switching the kernel in the Jupyter notebook.

# %% [markdown]
# ## Git
# Git is a popular version control system that is used to track changes in computer files and facilitate collaboration on these files among multiple individuals. It is particularly useful for group projects and is a valuable skill to possess. To use Git as the version control system for your group project, you will need a server that hosts the project. One well-known option is Microsoft's GitHub. The university also hosts a Git server, too. It is available for free to university members. To access Gitlab, go to https://gitlab.gwdg.de/ and log in with your university account through AcademicID. From there, you can create a new project and add your group members as developers, who can be identified by their university email address. Once the project is set up, you can copy the link to clone the project onto your local machine. For more information on installing, cloning a repository, and using Git in general, please refer to https://git-scm.com/book/en/v2/Getting-Started-Installing-Git, https://git-scm.com/book/en/v2/Git-Basics-Getting-a-Git-Repository, and https://git-scm.com/book/en/v2 , respectively.

# %% [markdown]
# ## Linux Server
# During the project phase you do not have to come to the PC pool to work on the servers. You can also work on the server from your local machine at home. On how to do it, please look into *linux_server_instructions.pdf* .

# %% [markdown]
# ## TensorBoard
# TensorBoard is a powerful tool that allows you to visualize various kinds of aspects of the training process of your neural network. Although TensorBoard was developed for TensorFlow, it can also be used with PyTorch. Getting to grips with TensorBoard is certainly beneficial in order to assess the performance of your models. Particularly if you are working remotely on the lab's servers. However, you can also rely on other means of keeping track of your model's performance if TensorBoard is not an option for you. Should you be limited by the Jupyter Cloud, which does not allow for using TensorBoard, then you can still try it once you have access to the lab's servers. You can find general information about TensorBoard on these websites - https://pytorch.org/tutorials/recipes/recipes/tensorboard_with_pytorch.html and https://www.tensorflow.org/tensorboard/get_started - and information how to start TensorBoard in the pdf *TensorBoard_instructions.pdf* .

# %% [markdown]
# ## Type Hints:
# The code that comes with the notebooks contains type hints. If you haven’t heard of type hints yet, the following website provides a short explanation - https://docs.python.org/3/library/typing.html - and the pdf *TypeHints_examples.pdf* provides a little more information and some examples.

# %% [markdown]
# ***

# %% [markdown]
# ## Task Overview
# ### Task Set 1: Data
#
# 1. Visualize 5 examples of each class from Cifar10 train set using Pyplot
# 2. Plot a histogram of the number of images per class in the Cifar10 train set.
# 3.
#     * Write a function which splits the downloaded Cifar10 train set into a train and validation set.
#     * Download the Cifar10 test set.
#     * Implement a transformation pipeline which changes the hue, and randomly crops and resizes the images. The transformation pipeline should only be applied to the training set and not to the validation and test set. If you can, try to implement the transformation pipeline as a wrapper around the train set such that the augmentation is applied on the fly when the dataloader loads the images for each mini batch. Keep in mind, that you use the augmented images in addition to the original images for training.
# 4. Visualize 5 transformed train set samples of your choice and compare them to the originals.
#
# ### Task Set 2: Model and Training Loop
# 1. Build a class CifarCNN which should resemble a CNN for classification. The class's __init\_\_-method should have a parameter for scaling the number of filters in the convolutional layers.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;The CNN should:<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;- use ReLU and BatchNorm after each convolutional layer,<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;- use Residual Connections between the convolutional layers,<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;- end with a global adaptive avg. pool layer followed by a linear layer, and<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;- make sure to adapt the model such that the receptive field up to the global adaptive avg. pool captures at least half of the image.<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; All other details like the number of convolutional layers are up to you.
#
# 2. Create a tensor consisting of only ones whose
#     *  first dimension is for the batch size with a size of your choice,
#     *  second dimension is for the number of color channels, and
#     *  the third and fourth dimension being for the image's width and length, respectively.
#     -> Use a CIFAR10 image's characteristics here.
#
#     Then, instantiate your model, forward the tensor through the model, and check if the model's output is the one you expected.
#
# 3. Write a function that counts the trainable/non-trainable parameters of the network.
# 4. Implement a training loop using PyTorch's DataLoader. Make sure that the model's parameters are saved to your local machine after training.
#
# ### Task Set 3: CIFAR Training
# 1. Train the model using your augmented train set and track the progress of training (classification accuracy on the training and validation set) using TensorBoard. Set the number of epochs to 20.
# 2. Train another model with the same architecture but with a bigger scaling factor for the number of filters. Compare the results of the two models. Track the progress of training (classification accuracy and loss on the training and validation set) using TensorBoard such that you can compare the two models in the same TensorBoard session. Be aware to not overwrite your already existing logs and model parameters. <br>
#
# *Note*: After watching the models' accuracy and loss curves, consider using a learning rate scheduler as `torch.optim.lr_scheduler.StepLR` and possibly retrain the model which would profit from it. It may improve the model's performance.
#
# ### Task Set 4: Exploration and Evaluation
# 1. Plot the first layer's learned weights, i.e. the kernels, of the model that performed better w.r.t. accuracy.
# 2. Plot the features of the first layer of the model that performed better w.r.t. accuracy for one test set image of your choice.
# 3. Plot a confusion matrix for predicting the classes of the test set using seaborn. Are there any classes that are hard to distinguish? Do that for both models.
# 4. Extract the feature vectors before applying `nn.flatten` and `self.linear` and visualize the set of feature vectors using t-SNE on a pyplot scatter plot. Do class-wise clusters emerge? Do that for both models.
#
# ### Task Set 5: Transfer Learning
# 1. Use a pretrained ResNet18 from torchvision.models and change the last linear layer for performing classification on the Cifar10 dataset.
# 2. Finetune the modified ResNet18 on the CIFAR10 dataset. Do use the augmented train set from task 2.1.1. Track the progress of training (classification accuracy and loss on the training and validation set) using TensorBoard such that you can compare all models in the same TensorBoard session. Be aware to not overwrite your already existing logs and model parameters. Try 20 epochs first, but be aware of overfitting.
# 3. Plot a confusion matrix for predicting the classes of the test set using seaborn. Is there an improvement compared to the best model from task 3?
# 4. Extract the feature vectors before applying `nn.flatten` and `self.linear` and visualize the set of feature vectors using t-SNE on a pyplot scatter plot. Is there a difference compared to the best model from task 3?

# %% [markdown]
# ## Library Imports

# %% [markdown]
# We have used the following libraries in this notebook for our solutions. Take this as a hint if you want or feel free to approach the tasks with different libraries, except for the PyTorch libraries which are not to be substituted by TensorFlow or similar.

# %%
import ast
import inspect
from PIL import Image
import shutil
import ssl
import sys
import os
import time
from typing import Any, Tuple, List, Generator, Optional, Dict

from matplotlib import pyplot as plt
import matplotlib.patches as mpatches
import matplotlib
import numpy as np
import seaborn as sns
from sklearn.manifold import TSNE
import sklearn.metrics
import tensorboard
from torch.utils.tensorboard import SummaryWriter
import torch
from torch import nn
from torch.nn import functional as nnf
from torch.utils.data import DataLoader, Dataset, random_split
from torchvision.datasets import CIFAR10
from torchvision.utils import make_grid
import torchvision.models
import torchvision.transforms as transforms
import torch
import pandas as pd
import seaborn as sns
import fastprogress
import time
import torch.nn.functional as F

# %% [markdown]
# ## Prerequisites - Dataset download

# %% [markdown]
# Depending on the given operating system, and if not done yet, the following cell creates a new directory for the CIFAR10 dataset's train set and downloads CIFAR10 into the newly created directory.

# %%
# Due to an SSL error message, the following line might be needed. You don't need to pay attention to this.
# ssl._create_default_https_context = ssl._create_unverified_context

# %%
def get_cifar(trainset: bool = True) -> CIFAR10:
    """Downloads the CIFAR10 dataset. For the download the directory `datasets/Cifar10` is created. 
    If the directory already exists, it is not created again. If the dataset is already downloaded, it is not downloaded again.
    This function works on Windows, Linux and MacOS.

    Args:
        trainset (bool, optional): Whether to return the CIFAR training set or the test set. Defaults to True.

    Returns:
        CIFAR10: The CIFAR10 dataset. Either the training set or the test set.
    """
    dir_of_interest: str = os.path.join(os.getcwd(), "datasets", "Cifar10")
    cifar_exists: bool = os.path.exists(dir_of_interest)
    if not cifar_exists:
        os.makedirs(dir_of_interest)
    Cifar10: CIFAR10 = CIFAR10(dir_of_interest, download=True, train=trainset)

    return Cifar10


Cifar10 = get_cifar()
# Out:
# Files already downloaded and verified

# %% [markdown]
# ## Task Set 1: Data
#
# 1. Visualize 5 examples of each class from Cifar10 train set using Pyplot
# 2. Plot a histogram of the number of images per class in the Cifar10 train set.
# 3.
#     * Write a function which splits the downloaded Cifar10 train set into a train and validation set.
#     * Download the Cifar10 test set.
#     * Implement a transformation pipeline which changes the hue, and randomly crops and resizes the images. The transformation pipeline should only be applied to the training set and not to the validation and test set. If you can, try to implement the transformation pipeline as a wrapper around the train set such that the augmentation is applied on the fly when the dataloader loads the images for each mini batch. Keep in mind, that you use the augmented images in addition to the original images for training.
# 4. Visualize 5 transformed train set samples of your choice and compare them to the originals.

# %% [markdown]
# ### 1. Visualize 5 examples of each class from Cifar10 train set using Pyplot

# %%
path="/kaggle/working"

# %%
dict={0:"airplane",
1:"automobile",
2:"bird",
3:"cat",
4:"deer",
5:"dog",
6:"frog",
7:"horse",
8:"ship",
9:"truck"}

# %%
#function for visualizing the images in our dataset
def visua(trainset, nr_row, nr_col, index=None):
    fig, axes = plt.subplots(nr_row, nr_col,figsize=(15,15))
    image, label = next(iter(trainset))
    if index != None:
        k=index
    else:
        k=torch.randint(0,10000,(5,))
    i=0
    for ax in axes.flatten():
        image, label = trainset.__getitem__(k[i])
        ax.axis('off')
        ax.imshow(image)
        ax.set_title(f"Class: {dict[label]}")
        i+=1
        
    fig.tight_layout()
    plt.show()
    return k
inedex= visua(Cifar10,1,5)

# %% [markdown]
# ### 2. Plot a histogram of the number of images per class in the Cifar10 train set.

# %%
labels = []
for i in range(len(Cifar10)):
    labels.append({dict[Cifar10[i][1]]})

# %%
df = pd.DataFrame(labels, columns = ['Classes'])

# %%
#histogram with number of samples
sns.histplot(data=df, y='Classes').set(title = "Sampels per class Cifar10 Trainset")
# Out:
# [Text(0.5, 1.0, 'Sampels per class Cifar10 Trainset')]

# %% [markdown]
# ### 3. Write a function which splits the downloaded Cifar10 train set into a train and validation set, create a train and validation set, download the Cifar10 test set and implement a transformation pipeline as described above.

# %%
#The splitting function is defined a little bit later
transform = transforms.Compose([
    transforms.ColorJitter(hue=0.3),  
    transforms.RandomCrop(17),        
    transforms.Resize(32),            
               
])

# Load the CIFAR-10 training dataset
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=None)

# Create a transformed version of the dataset using the same transform pipeline
transformed_trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)

# Concatenate the original and transformed datasets
concat_trainset = torch.utils.data.ConcatDataset([trainset, transformed_trainset])

# Create a data loader to load the concatenated dataset in batches
trainloader = torch.utils.data.DataLoader(concat_trainset, batch_size=32, shuffle=True, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ### 4. Visualize 5 transformed train set samples of your choice and compare them to the originals.

# %%
#transformed
index = visua(transformed_trainset,1,5)
#original
index2 = visua(trainset,1,5, index)

# %% [markdown]
# ### Tipps:
# * On task 1.1: The class CIFAR10 *(Documentation: https://pytorch.org/vision/stable/generated/torchvision.datasets.CIFAR10.html)* does not only grants you access to the images and labels by using the class's `__getitem__` special method (also sometimes called magic method or dunder method), but also through its attributes. Therefore, check out what Cifar10's `__dir__()` method returns and if anything of the return is useful for task 1.1.
# * On task 1.3.1: Look into the documentation of the `torch.utils.data.random_split` function.
# * On task 1.3.3: Look into the documentation of the `torchvision.transforms` module. It may happen that using functions of the `torchvision.transforms` module on the whole dataset at once leads to memory issues when not having enough RAM or swap space (in this case the kernel may crash without an error message describing a memory issue). Hence the suggestion of implementing the transformation pipeline as a wrapper around the train set. For example, build a custom PyTorch Dataset class as a wrapper by making use of its `__getitem__` method *(see: https://pytorch.org/tutorials/beginner/basics/data_tutorial.html#creating-a-custom-dataset-for-your-files)*. In the end, the following happens step by step if an image is drawn:
#     * 1. Call the `__getitem__` method of the custom dataset class, e.g. `CustomDataset[0]`,
#     * 2. The CustomDataset's `__getitem__` method then calls the `__getitem__` method of the Subset class created for the train set by the `torch.utils.data.random_split` function, e.g. `train_set[0]`,
#     * 3. The `__getitem__` method of the Subset class then calls the `__getitem__` method of the CIFAR10 class using the index assigned by the `torch.utils.data.random_split` function,
#     * 4. After an (image, label) tuple is returned by the CIFAR10 class within the CustomDataset's `__getitem__` method, the image can be transformed and is finally returned by the CustomDataset's `__getitem__` method.
#
#     `CustomDataset[0]` -> `train_set[0]` -> `CIFAR10[x]` -> (image, label) -> possibly transform image -> (transformed image, label) -> `CustomDataset[0]` returns (transformed image, label)

# %% [markdown]
# ## Task Set 2: Model and Training Loop
# 1. Build a class CifarCNN which should resemble a CNN for classification. The class's __init\_\_-method should have a parameter for scaling the number of filters in the convolutional layers.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;The CNN should:<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;- use ReLU and BatchNorm after each convolutional layer,<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;- use Residual Connections,<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;- end with a global adaptive avg. pool layer followed by a linear layer, and<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;- make sure to adapt the model such that the receptive field up to the global adaptive avg. pool captures at least half of the image.<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; All other details like the number of convolutional layers are up to you.
#
# 2. Create a tensor consisting of only ones whose
#     *  first dimension is for the batch size with a size of your choice,
#     *  second dimension is for the number of color channels, and
#     *  the third and fourth dimension being for the image's width and length, respectively.
#     -> Use a CIFAR10 image's characteristics here.
#
#     Then, instantiate your model, forward the tensor through the model, and check if the model's output is the one you expected.
#
# 3. Write a function that counts the trainable/non-trainable parameters of the network.
# 4. Implement a training loop using PyTorch's DataLoader. Make sure that the model's parameters are saved to your local machine after training.

# %% [markdown]
# ### 1. Build a class CifarCNN as described above

# %%
def get_device(cuda_preference=True):
    """Gets pytorch device object. If cuda_preference=True and 
        cuda is available on your system, returns a cuda device.
    
    Args:
        cuda_preference: bool, default True
            Set to true if you would like to get a cuda device
            
    Returns: pytorch device object
            Pytorch device
    """
    
    print('cuda available:', torch.cuda.is_available(), 
          '; cudnn available:', torch.backends.cudnn.is_available(),
          '; num devices:', torch.cuda.device_count())
    
    use_cuda = False if not cuda_preference else torch.cuda.is_available()
    device = torch.device('cuda:0' if use_cuda else 'cpu')
    device_name = torch.cuda.get_device_name(device) if use_cuda else 'cpu'
    print('Using device', device_name)
    return device

# DO NOT CHANGE
device = get_device()

# Get number of cpus to use for faster parallelized data loading
num_cpus = os.cpu_count()
print(num_cpus, 'CPUs available')
# Out:
# cuda available: True ; cudnn available: True ; num devices: 2
# Using device Tesla T4
# 2 CPUs available

# %%
# The following functions for splitting, training and plotting were part of the work done in the DL lecture
def grab_data(data_dir, num_cpus=1):

    trainset = torchvision.datasets.CIFAR10(data_dir, train=True, download=True, 
                                            transform=torchvision.transforms.ToTensor())

    # Get normalization transform
    num_samples = trainset.data.shape[0]
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=num_samples, 
                                              num_workers=num_cpus)
    imgs, _ = next(iter(trainloader))
    dataset_mean = torch.mean(imgs, dim=(0,2,3))
    dataset_std = torch.std(imgs, dim=(0,2,3))

    normalized_transform = torchvision.transforms.Compose([
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize(dataset_mean, dataset_std)
    ])

    # Load again, now normalized
    trainset = torchvision.datasets.CIFAR10(data_dir, download=True, train=True, 
                                            transform=normalized_transform) 
    # Apply the same transform, computed from the train-set, to the test-set
    # so both have a similar distribution. We do not normalize the test-set directly,
    # since we are not allowed to perform any computations with it. (We only use it
    # for reporting results in the very end)
    testset = torchvision.datasets.CIFAR10(data_dir, download=True, train=False, 
                                           transform=normalized_transform)

    return trainset, testset, dataset_mean, dataset_std
        
        
def generate_train_val_data_split(trainset, split_seed=42, val_frac=0.2):
    """Splits train dataset into train and validation dataset.

    Args:
        trainset (CIFAR10): CIFAR10 trainset object
        split_seed (int, optional): Seed used to randomly assign data
            points to the validation set. Defaults to 42.
        val_frac (float, optional): Fraction of training set that should be 
            split into validation set. Defaults to 0.2.

    Returns:
        CIFAR10, CIFAR10: CIFAR10 trainset and validation set.
    """
    num_val_samples = np.ceil(val_frac * trainset.data.shape[0]).astype(int)
    num_train_samples = trainset.data.shape[0] - num_val_samples
    trainset, valset = torch.utils.data.random_split(trainset, 
                                  (num_train_samples, num_val_samples), 
                                  generator=torch.Generator().manual_seed(split_seed))
    return trainset, valset
    
    
def init_data_loaders(trainset, valset, testset, batch_size=1024, num_cpus=1):
    
    trainloader = torch.utils.data.DataLoader(trainset,
                                                   batch_size=batch_size,
                                                   shuffle=True,
                                                   num_workers=num_cpus)
    valloader = torch.utils.data.DataLoader(valset, 
                                                 batch_size=batch_size,
                                                 shuffle=True,
                                                 num_workers=num_cpus)
    testloader = torch.utils.data.DataLoader(testset,
                                                  batch_size=batch_size,
                                                  shuffle=True, 
                                                  num_workers=num_cpus)
    return trainloader, valloader, testloader### 3. Write a function that counts the trainable/non-trainable parameters of the network.

# %%
def accuracy(correct, total): 

    return float(correct)/total


def train(dataloader, optimizer, model, loss_fn, device, master_bar):
    """Run one training epoch.

    Args:
        dataloader (DataLoader): Torch DataLoader object to load data
        optimizer: Torch optimizer object
        model (nn.Module): Torch model to train
        loss_fn: Torch loss function
        device (torch.device): Torch device to use for training
        master_bar (fastprogress.master_bar): Will be iterated over for each
            epoch to draw batches and display training progress

    Returns:
        float, float: Mean loss of this epoch, fraction of correct predictions
            on training set (accuracy)
    """
    epoch_loss = []
    epoch_correct, epoch_total = 0, 0

    for x, y in fastprogress.progress_bar(dataloader, parent=master_bar):
        optimizer.zero_grad()
        model.train()

        # Forward pass
        y_pred = model(x.to(device))

        # For calculating the accuracy, save the number of correctly classified 
        # images and the total number
        epoch_correct += sum(y.to(device) == y_pred.argmax(dim=1))
        epoch_total += len(y)

        # Compute loss
        loss = loss_fn(y_pred, y.to(device))

        # Backward pass
        loss.backward()
        optimizer.step()

        # For plotting the train loss, save it for each sample
        epoch_loss.append(loss.item())

    # Return the mean loss and the accuracy of this epoch
    return np.mean(epoch_loss), accuracy(epoch_correct, epoch_total)


def validate(dataloader, model, loss_fn, device, master_bar):
    """Compute loss, accuracy and confusion matrix on validation set.

    Args:
        dataloader (DataLoader): Torch DataLoader object to load data
        model (nn.Module): Torch model to train
        loss_fn: Torch loss function
        device (torch.device): Torch device to use for training
        master_bar (fastprogress.master_bar): Will be iterated over to draw 
            batches and show validation progress

    Returns:
        float, float, torch.Tensor shape (10,10): Mean loss on validation set, 
            fraction of correct predictions on validation set (accuracy)
    """
    epoch_loss = []
    epoch_correct, epoch_total = 0, 0
    confusion_matrix = torch.zeros(10, 10)    

    model.eval()
    with torch.no_grad():
        for x, y in fastprogress.progress_bar(dataloader, parent=master_bar):
            # make a prediction on validation set
            y_pred = model(x.to(device))

            # For calculating the accuracy, save the number of correctly 
            # classified images and the total number
            epoch_correct += sum(y.to(device) == y_pred.argmax(dim=1))
            epoch_total += len(y)

            # Fill confusion matrix
            for (y_true, y_p) in zip(y, y_pred.argmax(dim=1)):
                confusion_matrix[int(y_true), int(y_p)] +=1

            # Compute loss
            loss = loss_fn(y_pred, y.to(device))

            # For plotting the train loss, save it for each sample
            epoch_loss.append(loss.item())

    # Return the mean loss, the accuracy and the confusion matrix
    return np.mean(epoch_loss), accuracy(epoch_correct, epoch_total), confusion_matrix


def run_training(model, optimizer, loss_function, device, num_epochs, 
                train_dataloader, val_dataloader, sched = None,early_stopper=None, verbose=False):
    """Run model training.

    Args:
        model (nn.Module): Torch model to train
        optimizer: Torch optimizer object
        loss_fn: Torch loss function for training
        device (torch.device): Torch device to use for training
        num_epochs (int): Max. number of epochs to train
        train_dataloader (DataLoader): Torch DataLoader object to load the
            training data
        val_dataloader (DataLoader): Torch DataLoader object to load the
            validation data
        early_stopper (EarlyStopper, optional): If passed, model will be trained
            with early stopping. Defaults to None.
        verbose (bool, optional): Print information about model training. 
            Defaults to False.

    Returns:
        list, list, list, list, torch.Tensor shape (10,10): Return list of train
            losses, validation losses, train accuracies, validation accuracies
            per epoch and the confusion matrix evaluated in the last epoch.
    """
    start_time = time.time()
    master_bar = fastprogress.master_bar(range(num_epochs))
    train_losses, val_losses, train_accs, val_accs = [],[],[],[]
    early_stopper = early_stopper

    for epoch in master_bar:
        # Train the model
        epoch_train_loss, epoch_train_acc = train(train_dataloader, optimizer, model, 
                                                  loss_function, device, master_bar)
        # Validate the model
        epoch_val_loss, epoch_val_acc, confusion_matrix = validate(val_dataloader, 
                                                                   model, loss_function, 
                                                                   device, master_bar)

        # Save loss and acc for plotting
        train_losses.append(epoch_train_loss)
        val_losses.append(epoch_val_loss)
        train_accs.append(epoch_train_acc)
        val_accs.append(epoch_val_acc)
        
        if verbose:
            master_bar.write(f'Train loss: {epoch_train_loss:.2f}, val loss: {epoch_val_loss:.2f}, train acc: {epoch_train_acc:.3f}, val acc {epoch_val_acc:.3f}')
            
        if early_stopper:
            ####################
            ## YOUR CODE HERE ##
            ####################
            #raise NotImplementedError # Comment out this keyword after your implementation
            if(len(val_accs)>3):
                if(early_stopper.check(val_accs)==True):
                    break
            
            # END OF YOUR CODE #
            
    time_elapsed = np.round(time.time() - start_time, 0).astype(int)
    print(f'Finished training after {time_elapsed} seconds.')
    return train_losses, val_losses, train_accs, val_accs, confusion_matrix


def plot(title, label, train_results, val_results, yscale='linear', save_path=None, 
         extra_pt=None, extra_pt_label=None):
    """Plot learning curves.

    Args:
        title (str): Title of plot
        label (str): x-axis label
        train_results (list): Results vector of training of length of number
            of epochs trained. Could be loss or accuracy.
        val_results (list): Results vector of validation of length of number
            of epochs. Could be loss or accuracy.
        yscale (str, optional): Matplotlib.pyplot.yscale parameter. 
            Defaults to 'linear'.
        save_path (str, optional): If passed, figure will be saved at this path.
            Defaults to None.
        extra_pt (tuple, optional): Tuple of length 2, defining x and y coordinate
            of where an additional black dot will be plotted. Defaults to None.
        extra_pt_label (str, optional): Legend label of extra point. Defaults to None.
    """
    
    epoch_array = np.arange(len(train_results)) + 1
    train_label, val_label = "Training "+label.lower(), "Validation "+label.lower()
    
    sns.set(style='ticks')

    plt.plot(epoch_array, train_results, epoch_array, val_results, linestyle='dashed', marker='o')
    legend = ['Train results', 'Validation results']
    
    if extra_pt:
        ####################
        ## YOUR CODE HERE ##
        ####################
        raise NotImplementedError # Comment out this keyword after your implementation

        # END OF YOUR CODE #
        
    plt.legend(legend)
    plt.xlabel('Epoch')
    plt.ylabel(label)
    plt.yscale(yscale)
    plt.title(title)
    
    sns.despine(trim=True, offset=5)
    plt.title(title, fontsize=15)
    if save_path:
        plt.savefig(str(save_path), bbox_inches='tight')
    plt.show()

# %%
# We've concatenated the augumented data for the training
trainset1, testset, dataset_mean, dataset_std = grab_data(path)
trainset = torch.utils.data.ConcatDataset([trainset1, transformed_trainset])
trainset, valset = generate_train_val_data_split(trainset1, split_seed=42, val_frac=0.2)
trainloader, valloader, testloader = init_data_loaders(trainset, valset, testset, batch_size=1024, num_cpus=1)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
#Model
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        residual = self.shortcut(x)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out += residual
        out = self.relu(out)
        return out

class CifarCnn(nn.Module):
    def __init__(self, in_channels=3, num_classes=10, num_filters=16):
        super(CifarCnn, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, num_filters, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(num_filters)
        self.relu = nn.ReLU(inplace=True)
        self.layer1 = nn.Sequential(
            ResidualBlock(num_filters, num_filters),
            ResidualBlock(num_filters, num_filters)
        )
        self.layer2 = nn.Sequential(
            ResidualBlock(num_filters, num_filters*2, stride=2),
            ResidualBlock(num_filters*2, num_filters*2)
        )
        self.layer3 = nn.Sequential(
            ResidualBlock(num_filters*2, num_filters*4, stride=2),
            ResidualBlock(num_filters*4, num_filters*4)
        )
        self.layer4 = nn.Sequential(
            ResidualBlock(num_filters*4, num_filters*8, stride=2),
            ResidualBlock(num_filters*8, num_filters*8)
        )
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(num_filters*8, num_classes)

        self.receptive_field = 3 # initial receptive field size
        self.receptive_field_stride = 1 
        for layer in [self.layer1, self.layer2, self.layer3, self.layer4]:
            for block in layer:
                self.receptive_field += (block.conv1.kernel_size[0] - 1) * self.receptive_field_stride
                self.receptive_field_stride *= block.conv1.stride[0]
        
        
        assert self.receptive_field >= 16, "Receptive field size too small for input image size"

    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out

# %% [markdown]
# ### 2. Create a tensor consisting of only ones and test your model class as described above.

# %%
# also the training loop is done here
ones = torch.ones((10,3,32,32))
model = CifarCnn()
model.eval()
output = model(ones)
print(output)
# Theoretically this is an expected output since softmax + cross entropy will be applied after in a usual case
# Out:
# tensor([[ 0.0668,  0.0670, -0.0095, -0.0594,  0.0726,  0.0646, -0.0044, -0.0504,
#          -0.0715, -0.0125],
#         [ 0.0668,  0.0670, -0.0095, -0.0594,  0.0726,  0.0646, -0.0044, -0.0504,
#          -0.0715, -0.0125],
#         [ 0.0668,  0.0670, -0.0095, -0.0594,  0.0726,  0.0646, -0.0044, -0.0504,
#          -0.0715, -0.0125],
#         [ 0.0668,  0.0670, -0.0095, -0.0594,  0.0726,  0.0646, -0.0044, -0.0504,
#          -0.0715, -0.0125],
#         [ 0.0668,  0.0670, -0.0095, -0.0594,  0.0726,  0.0646, -0.0044, -0.0504,
#          -0.0715, -0.0125],
#         [ 0.0668,  0.0670, -0.0095, -0.0594,  0.0726,  0.0646, -0.0044, -0.0504,
#          -0.0715, -0.0125],
#         [ 0.0668,  0.0670, -0.0095, -0.0594,  0.0726,  0.0646, -0.0044, -0.0504,
#          -0.0715, -0.0125],
#         [ 0.0668,  0.0670, -0.0095, -0.0594,  0.0726,  0.0646, -0.0044, -0.0504,
#          -0.0715, -0.0125],
#         [ 0.0668,  0.0670, -0.0095, -0.0594,  0.0726,  0.0646, -0.0044, -0.0504,
# ...

# %%
#the function counts the number of learnable parameters for a g
def count_parameters(model):
    
    train_para = sum(i.numel() for i in model.parameters() if i.requires_grad)
    no_train_para = sum(i.numel() for i in model.parameters() if not i.requires_grad)
    
    return train_para, no_train_para

count_parameters(model)
# Out:
# (2797610, 0)

# %% [markdown]
# ### 4. Implement a training loop using PyTorch DataLoader. Make sure that the model's parameters are saved to your local machine after training.

# %%
path2 = '/kaggle/model'
torch.save(model.state_dict(), path2)

# %% [markdown]
# ### Tipps:
# * On task 2.1: Use the base class nn.Module to build your model class *(see https://pytorch.org/docs/stable/generated/torch.nn.Module.html)* and the classes offered by the nn package *(see https://pytorch.org/docs/stable/nn.html)*. The global adaptive avg. pool layer means to have an output size of 1 for each dimension of the input tensor.
# * On task 2.3: Can parameters that don't require a gradient be trained? Make yourself familiar with the `requires_grad` attribute of the `torch.Tensor` class *(see https://pytorch.org/docs/stable/generated/torch.Tensor.html#torch.Tensor.requires_grad)* and with the `parameters()` method of the `nn.Module` class *(see https://pytorch.org/docs/stable/generated/torch.nn.Module.html#torch.nn.Module.parameters)*.
# * On task 2.4: Remember from the Deep Learning lecture which loss function to use for classification tasks and what optimizers there are. Make yourself familiar with the `torch.optim` package *(see https://pytorch.org/docs/stable/optim.html)*. You can also draw inspiration from this tutorial: *https://pytorch.org/tutorials/beginner/basics/optimization_tutorial.html* . For saving the model's parameters, make yourself familiar with the `torch.save` function *(see https://pytorch.org/docs/stable/generated/torch.save.html)*, `torch.load` function *(see https://pytorch.org/docs/stable/generated/torch.load.html)*, and the `state_dict` attribute of the `nn.Module` class *(see https://pytorch.org/docs/stable/generated/torch.nn.Module.html#torch.nn.Module.state_dict)*.

# %% [markdown]
# ## Task Set 3: CIFAR Training
#
# 1. Train the model using your augmented train set and track the progress of training (classification accuracy on the training and validation set) using TensorBoard. Set the number of epochs to 20.
# 2. Train another model with the same architecture but with a bigger scaling factor for the number of filters. Compare the results of the two models. Track the progress of training (classification accuracy and loss on the training and validation set) using TensorBoard such that you can compare the two models in the same TensorBoard session. Be aware to not overwrite your already existing logs and model parameters.
#
# *Note*: After watching the models' accuracy and loss curves, consider using a learning rate scheduler as `torch.optim.lr_scheduler.StepLR` and possibly retrain the model which would profit from it. It may improve the model's performance.

# %%
# Creates a device object representing the GPU (if available) or the CPU
device: torch.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# If you have a GPU and CUDA installed, but you don't want to use it, you can change the device to "cpu"
# device = torch.device("cpu")

# Note: It can be that the GPU is not used even if you set the device to "cuda". 
# This is because PyTorch does not utilize the GPU for models it considers small.
# Out:
# Using device: cuda

# %% [markdown]
# ### 1. Train the model as described above.

# %%
#here the default value of the filters is set to 16 in the CNN model, for the next one we increase the number of filters
lr=0.01    
  
model = CifarCnn()
model=model.to(device)
num_epochs=20
    
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr)
train_losses, val_losses, train_accs, val_accs, confusion_matrix=run_training(model, optimizer, loss_function, device, num_epochs,trainloader,valloader)
plot("Losses for lr = {}".format(lr), "Loss", train_losses, val_losses, yscale='linear', save_path=None, 
        extra_pt=None, extra_pt_label=None)
plot("Accs for lr = {}".format(lr), "Acc", train_accs, val_accs, yscale='linear', save_path=None, 
        extra_pt=None, extra_pt_label=None)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Finished training after 297 seconds.

# %% [markdown]
# ### 2. Train another model with the same architecture but with a bigger scaling factor for the number of filters as described above.

# %%
#the number of filters is increased this time
lr=0.01    
  
model = CifarCnn(num_filters=32)
model=model.to(device)
num_epochs=20
    
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr)
train_losses, val_losses, train_accs, val_accs, confusion_matrix=run_training(model, optimizer, loss_function, device, num_epochs,trainloader,valloader)
plot("Losses for lr = {}".format(lr), "Loss", train_losses, val_losses, yscale='linear', save_path=None, 
        extra_pt=None, extra_pt_label=None)
plot("Accs for lr = {}".format(lr), "Acc", train_accs, val_accs, yscale='linear', save_path=None, 
        extra_pt=None, extra_pt_label=None)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Finished training after 410 seconds.

# %%
#This is the training with the scheduler
lr=0.01    
  
model = CifarCnn(num_filters=32)
model=model.to(device)
num_epochs=20
    
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)
train_losses, val_losses, train_accs, val_accs, confusion_matrix=run_training(model, optimizer, loss_function, device, num_epochs,trainloader,valloader, sched =scheduler )
plot("Losses for lr = {}".format(lr), "Loss", train_losses, val_losses, yscale='linear', save_path=None, 
        extra_pt=None, extra_pt_label=None)
plot("Accs for lr = {}".format(lr), "Acc", train_accs, val_accs, yscale='linear', save_path=None, 
        extra_pt=None, extra_pt_label=None)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Finished training after 409 seconds.

# %% [markdown]
# ### Tipps:
# * On task 3.1 and 3.2:
#     * Make yourself familiar with the `torch.utils.tensorboard` package *(see https://pytorch.org/docs/stable/tensorboard.html)*.
#     * You can draw inspiration from this tutorial: *https://pytorch.org/tutorials//intermediate/tensorboard_tutorial.html* .
#     * For model comparison purposes in TensorBoard: TensorBoard recursively searches for event files in all subdirectories of the log directory which is passed to the SummaryWriter's constructor via the `log_dir` parameter *(see https://pytorch.org/docs/stable/tensorboard.html#torch.utils.tensorboard.writer.SummaryWriter)*. You can utilize this feature to log the training progress of multiple models in the same TensorBoard session. Therefore, you would need to create a subdirectory in the log directory, i.e. a folder, for each model you want to train.
#     * Also for model comparison purposes in TensorBoard: You can utilize the `main_tag` parameter of the SummaryWriter's `add_scalars` method *(see https://pytorch.org/docs/stable/tensorboard.html#torch.utils.tensorboard.writer.SummaryWriter.add_scalars)*. The `main_tag` parameter is used to group the added scalars in the TensorBoard UI into one graph which is named after the `main_tag` parameter.
#     * For not overwriting your already existing logs and model parameters, a simple solution is to make use of the `input()` function. This function waits for user input and returns it as a string. You could make the execution of the cell or function which would overwrite your already existing logs and model parameters dependent on the user's input.

# %% [markdown]
# ## Task Set 4: Exploration and Evaluation
# 1. Plot the first layer's learned weights, i.e. the kernels, of the model that performed better w.r.t. accuracy.
# 2. Plot the features of the first layer of the model that performed better w.r.t. accuracy for one test set image of your choice.
# 3. Plot a confusion matrix for predicting the classes of the test set using seaborn. Are there any classes that are hard to distinguish? Do that for both models.
# 4. Extract the feature vectors before applying `nn.flatten` and `self.linear` and visualize the set of feature vectors using t-SNE on a pyplot scatter plot. Do class-wise clusters emerge? Do that for both models.

# %% [markdown]
# ### 1. Plot the first layer's learned weights, i.e. the kernels, of the model that performed better w.r.t. accuracy.

# %%
print("Model's state_dict:")
for param_tensor in model.state_dict():
    print(param_tensor, "\t", model.state_dict()[param_tensor].size())
# Out:
# Model's state_dict:
# conv1.weight 	 torch.Size([32, 3, 3, 3])
# bn1.weight 	 torch.Size([32])
# bn1.bias 	 torch.Size([32])
# bn1.running_mean 	 torch.Size([32])
# bn1.running_var 	 torch.Size([32])
# bn1.num_batches_tracked 	 torch.Size([])
# layer1.0.conv1.weight 	 torch.Size([32, 32, 3, 3])
# layer1.0.bn1.weight 	 torch.Size([32])
# layer1.0.bn1.bias 	 torch.Size([32])
# layer1.0.bn1.running_mean 	 torch.Size([32])
# layer1.0.bn1.running_var 	 torch.Size([32])
# layer1.0.bn1.num_batches_tracked 	 torch.Size([])
# layer1.0.conv2.weight 	 torch.Size([32, 32, 3, 3])
# layer1.0.bn2.weight 	 torch.Size([32])
# layer1.0.bn2.bias 	 torch.Size([32])
# layer1.0.bn2.running_mean 	 torch.Size([32])
# layer1.0.bn2.running_var 	 torch.Size([32])
# layer1.0.bn2.num_batches_tracked 	 torch.Size([])
# layer1.1.conv1.weight 	 torch.Size([32, 32, 3, 3])
# layer1.1.bn1.weight 	 torch.Size([32])
# layer1.1.bn1.bias 	 torch.Size([32])
# layer1.1.bn1.running_mean 	 torch.Size([32])
# ...

# %%
# getting the first layer's weights, in our case we have a onvolutional layer 
for param_tensor in model.state_dict():
    layer1 = model.state_dict()[param_tensor]
    break
#normalizing the tensor  
norm = torch.norm(layer1, p=2, dim=(len(layer1.shape)-2,len(layer1.shape)-1), keepdim=True)
x_normalized = torch.div(layer1, norm)

# %%
#the weights of the filters
def visua2(tensor, nr_row, nr_col, index=None):
    fig, axes = plt.subplots(nr_row, nr_col,figsize=(15,15))
    i = 0
    for ax in axes.flatten():
        ax.axis('off')
        ax.imshow(tensor[i].cpu())
        ax.set_title(f"Filter Number: {i}")
        i+=1
        
    fig.tight_layout()
    plt.show()
visua2(x_normalized, 5, 6)

# %% [markdown]
# ### 2. Plot the features of the first layer of the model that performed better w.r.t. accuracy for one test set image of your choice.

# %%
first_layer = list(model.children())[0].cpu()
first_layer(torch.ones(3,3,32,32)).shape
def get_layers_features_w_new_model(layers,device, dataset, image_idx):
    image,label = dataset.__getitem__(image_idx)
    image = image[None,:]
    with torch.no_grad():
        features = layers(image)
    return features,label

# %%
def plot_features_of_first_layer(features: torch.Tensor, image: torch.Tensor) -> None:
    """
    Plots the features of the first layer of CifarCNN.
    Args:
        features (torch.Tensor): The features of the first layer of CifarCNN
    Returns:
        None
    """
    # Get the features of the first layer
    features: np.ndarray = features.numpy()

    # normalize each of the 16 features to the range [0, 1]
    #for i in range(features.shape[0]):
    #    features[i] = (features[i] - features[i].min()) / (features[i].max() - features[i].min())

    # Calculate the number of rows for 4 columns
    num_features: int = features.shape[0]
    num_rows: int = int(num_features/4)

    # Plot the 16 features of the first kernel
    fig, ax = plt.subplots(num_rows, 4)
    fig.set_figwidth(8)
    fig.set_figheight(8)
    fig.suptitle('features of the first kernel')
    for i in range(4):
        for j in range(num_rows):
            ax[j, i].imshow(features[i+j*4], cmap='gray')
            ax[j, i].axis('off')
    plt.show()

    # Plot the original image
    plt.figure(figsize=(2, 2))
    plt.title('Original image')
    print(image.shape)
    plt.imshow(image.permute(1,2,0))
    plt.axis('off')
    plt.show()
# Extract the layers of interest, i.e. the first layer of the model
first_layer: List[nn.Module] = model.conv1

features, whatever = get_layers_features_w_new_model(layers=first_layer, device=device, dataset=trainset, image_idx=6)
print(trainset[6][0].shape)
print(features.shape)
plot_features_of_first_layer(features[0], trainset[6][0])
# Out:
# torch.Size([3, 32, 32])
# torch.Size([1, 32, 32, 32])
# torch.Size([3, 32, 32])

# %%
classes = list(dict.values())

# %% [markdown]
# ### 3. Plot a confusion matrix for predicting the classes of the test set using seaborn. Are there any classes that are hard to distinguish? Do that for both models.

# %%
_, _ ,confusion = validate(testloader, model.to(device), loss_function, device, master_bar=None)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='10' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10/10 00:02&lt;00:00]
#     </div>

# %%
# the result will get better later
confusion = nn.functional.normalize(confusion)
sns.heatmap(confusion,  xticklabels=classes, yticklabels=classes, cmap="crest").set_title("Confusion for Testset")
# Out:
# Text(0.5, 1.0, 'Confusion for Testset')

# %% [markdown]
# ### 4. Extract the feature vectors before applying `nn.flatten` and `self.linear` and visualize the set of feature vectors using t-SNE on a pyplot scatter plot. Do class-wise clusters emerge? Do that for both models.

# %%
list(model.children())[:8]
# Out:
# [Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False),
#  BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
#  ReLU(inplace=True),
#  Sequential(
#    (0): ResidualBlock(
#      (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu): ReLU(inplace=True)
#      (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (shortcut): Sequential()
#    )
#    (1): ResidualBlock(
#      (conv1): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#      (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#      (relu): ReLU(inplace=True)
# ...

# %%
a= list(model.children())[:8][0]
#print(a)
num_features = 1000
feature_set = np.zeros((num_features,32768))
label_set = np.zeros(num_features)
for i in range(num_features):
    features,label = get_layers_features_w_new_model(layers=a, device=device, dataset= testset, image_idx=i)
    #print(features.shape)
    feature_set[i,:]=features.reshape(-1)
    label_set[i]=label
tsne = TSNE(n_components=2, verbose=1, random_state=123)
z = tsne.fit_transform(feature_set)
N = 10
cmap = plt.cm.jet
# extract all colors from the .jet map
cmaplist = [cmap(i) for i in range(cmap.N)]
# create the new map
cmap = cmap.from_list('Custom cmap', cmaplist, cmap.N)
scatter = plt.scatter(z[:,0],z[:,1],c=label_set.astype('int'),cmap=cmap)
plt.legend(handles=scatter.legend_elements()[0], labels=Cifar10.classes,loc='center left', bbox_to_anchor=(1, 0.5))
plt.suptitle('T-SNE of smaller Model`s last features')
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1000 samples in 0.021s...
# [t-SNE] Computed neighbors for 1000 samples in 0.747s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1000
# [t-SNE] Mean sigma: 29.275997
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 92.909637
# [t-SNE] KL divergence after 1000 iterations: 1.690702

# %% [markdown]
# ### Tipps:
#
# * On task 4.1: A way of accessing all the parameters, i.e. also the kernel's learned weights, would be through the `state_dict` attribute of the `nn.Module` class which you maybe already used for saving the model. See what type of object the `state_dict` attribute is and how this may help you to access the parameters of the first convolutional layer. Since the first layer's kernel is of shape *(Output_channel, Input_channel=3, Kernel_width, Kernel_height)* you can interpret the kernel as an image with three color channels. For visualizing the kernels, make yourself familiar with the weight tensor's shape. For plotting use the `matplotlib.pyplot` package.
# * On task 4.2: One way of accessing the features of the first layer would be to extract all layers needed, define a new nn.Module model class with all the extracted layers, and define the respective forward method. The extractions of a model's layers depends on your model's architecture. Single modules/layers of a model are accessible as the model's attribute. A way to extract multiple modules/layers is with the `children` method of the `nn.Module` class *(see https://pytorch.org/docs/stable/generated/torch.nn.Module.html#torch.nn.Module.children)*. For example, if you want to extract the first two layers of a model, you could do something like this: `list(model.children())[:2]`. To re-instantiate the model, you can use the `nn.Sequential` class *(see https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html#torch.nn.Sequential)*. However, one would need to unpack a list if passed to the `nn.Sequential` class. <br>Since the first layer's feature if of shape *(Batch_size, Output_channel, feature_width, feature_height)* you can interpret the each respective feature as an image with one color channel. The feature_width, feature_height depends on whether you've chosen same padding or not. For plotting use the `matplotlib.pyplot` package. Another very interesting yet more tedious way would be to use the `forward_hook` method of the `nn.Module` class *(see https://pytorch.org/docs/stable/generated/torch.nn.Module.html#torch.nn.Module.register_forward_hook)*. On how to use the `forward_hook` method, you can draw inspiration from this video: *https://www.youtube.com/watch?v=syLFCVYua6Q* .
# * On task 4.3: Make yourself familiar with the scikit-learn package's functions.
# * On task 4.4: Make yourself familiar with the scikit-learn package's functions. Follow the same procedure as in task 4.2.

# %% [markdown]
# ## Task Set 5: Transfer Learning
# 1. Use a pretrained ResNet18 from torchvision.models and change the last linear layer for performing classification on the Cifar10 dataset.
# 2. Finetune the modified ResNet18 on the CIFAR10 dataset. Do use the augmented train set from task 2.1.1. Track the progress of training (classification accuracy and loss on the training and validation set) using TensorBoard such that you can compare all models in the same TensorBoard session. Be aware to not overwrite your already existing logs and model parameters. Try 20 epochs first, but be aware of overfitting.
# 3. Plot a confusion matrix for predicting the classes of the test set using seaborn. Is there an improvement compared to the best model from task 3?
# 4. Extract the feature vectors before applying `nn.flatten` and `self.linear` and visualize the set of feature vectors using t-SNE on a pyplot scatter plot. Is there is there a difference compared to the best model from task 3?

# %% [markdown]
# ### 1. Use a pretrained ResNet18 from torchvision.models and change the last linear layer for performing classification on the Cifar10 dataset.

# %%
def get_resnet18(pretrained: bool = True) -> torchvision.models.resnet.ResNet:
    """
    Downloads the weights of the ResNet18 model, saves them in a new dir called 'ResNet18' in the project directory and returns an instance of the ResNet18 model.
    Either the model will be initialized as a pretrained model or the model is initialized with random weights.

    Args:
        pretrained (bool): If True, the weights learned on imagenet are downloaded, if False, the model is initialized with random weights.
    Returns:
        ResNet18 (torchvision.models.resnet.ResNet): An instance of the ResNet18 model.
    """
    if pretrained:
        path: str = os.path.join(os.getcwd(), "ResNet18")
        path_exists: bool = os.path.exists(path)

        if not path_exists:
            os.makedirs(path)

        torch.hub.set_dir(path)

        Resnet18 = torchvision.models.resnet18(weights = 'IMAGENET1K_V1')

    else:
        Resnet18 = torchvision.models.resnet18()

    return Resnet18

# %%
model = get_resnet18()

num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 10)

# %% [markdown]
# ### 2. Finetune the modified ResNet18 on the CIFAR10 dataset. Do use the augmented train set from task 2.1.1. Track the progress of training (classification accuracy on the training and validation set) using TensorBoard such that you can compare all models in the same TensorBoard session. Be aware to not overwrite your already existing logs and model parameters. Try 20 epochs first, but be aware of overfitting.

# %%
# We can clearly see better accuracies
lr=0.01    
  
model=model.to(device)
num_epochs=20
    
loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr)
train_losses, val_losses, train_accs, val_accs, confusion_matrix=run_training(model, optimizer, loss_function, device, num_epochs,trainloader,valloader)
plot("Losses for lr = {}".format(lr), "Loss", train_losses, val_losses, yscale='linear', save_path=None, 
        extra_pt=None, extra_pt_label=None)
plot("Accs for lr = {}".format(lr), "Acc", train_accs, val_accs, yscale='linear', save_path=None, 
        extra_pt=None, extra_pt_label=None)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Finished training after 283 seconds.

# %% [markdown]
# ### 3. Plot a confusion matrix for predicting the classes of the test set using seaborn. Is there an improvement compared to the best model from task 3?

# %%
_, _ ,confusion = validate(testloader, model.to(device), loss_function, device, master_bar=None)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='10' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [10/10 00:03&lt;00:00]
#     </div>

# %%
# The results for the confusion matrix are much better, as it can be seen!!!

confusion = nn.functional.normalize(confusion)
sns.heatmap(confusion,  xticklabels=classes, yticklabels=classes, cmap="crest").set_title("Confusion for Testset")
# Out:
# Text(0.5, 1.0, 'Confusion for Testset')

# %% [markdown]
# ### 4. Extract the feature vectors before applying `nn.flatten` and `self.linear` and visualize the set of feature vectors using t-SNE on a pyplot scatter plot. Is there is there a difference compared to the best model from task 3?

# %%
list(model.children())[:9]
a= list(model.children())[:8][0]
#print(a)
num_features = 1000
feature_set = np.zeros((num_features,16384))
label_set = np.zeros(num_features)
for i in range(num_features):
    features,label = get_layers_features_w_new_model(layers=a, device=device, dataset= testset, image_idx=i)
    #print(features.shape)
    feature_set[i,:]=features.reshape(-1)
    label_set[i]=label
tsne = TSNE(n_components=2, verbose=1, random_state=123)
z = tsne.fit_transform(feature_set)
N = 10
cmap = plt.cm.jet
# extract all colors from the .jet map
cmaplist = [cmap(i) for i in range(cmap.N)]
# create the new map
cmap = cmap.from_list('Custom cmap', cmaplist, cmap.N)
scatter = plt.scatter(z[:,0],z[:,1],c=label_set.astype('int'),cmap=cmap)
plt.legend(handles=scatter.legend_elements()[0], labels=Cifar10.classes,loc='center left', bbox_to_anchor=(1, 0.5))
plt.suptitle('T-SNE of Resnet Model`s last features')
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /opt/conda/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1000 samples in 0.011s...
# [t-SNE] Computed neighbors for 1000 samples in 0.387s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1000
# [t-SNE] Mean sigma: 68.668032
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 116.014549
# [t-SNE] KL divergence after 1000 iterations: 1.993407

# %% [markdown]
# ### Tipps
# * On task 5.1: If you print the model you'll see a summary of all the models modules/layers. Remember task 4.2 on how to access a module's module/layer.
# * On task 5.2: Same as in task set 3. You will possibly need to try different learning rates. On how to read the training loss and validation loss lines in TensorBoard w.r.t. the learning rate take a look into the Deep Learning lecture.
# * On task 5.3: Same as in task set 4.3.
# * On task 5.4: Same as in task set 4.4.
